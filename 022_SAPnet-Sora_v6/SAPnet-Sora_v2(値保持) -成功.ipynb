# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
def SQL_SetUp(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データベースファイルが存在する場合は処理を終了
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
    existing_tables = cursor.fetchall()
    if existing_tables:
        print("Database already exists. Exiting setup.")
        conn.close()
        return

    # テーブルを作成
    cursor.execute('''
        CREATE TABLE knowledge (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            angle FLOAT,
            distance FLOAT,
            activation FLOAT DEFAULT 0,
            description TEXT
        )
    ''')

    data = [
        ("直進", 333.44, 1.12, 0),#１番の知識
        ("左寄りの直進", 345.97, 1.03, 0),#２番の知識
        ("右寄りの直進", 0, 1, 0),#１番の知識
        ("右寄りの直進", 14.04, 1.03, 0),#１番の知識
        ("直進", 26.56, 1.12, 0)#１番の知識
    ]

    # データを挿入
    cursor.executemany("INSERT INTO knowledge (description, angle, distance, activation) VALUES (?, ?, ?, ?)", data)

    conn.commit()
    conn.close()

def SQL_GetData(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データを取得してDataFrameに格納
    cursor.execute("SELECT * FROM knowledge")
    rows = cursor.fetchall()
    columns = [description[0] for description in cursor.description]
    df = pd.DataFrame(rows, columns=columns)

    conn.close()

    return df

# 新しいデータを追加
def SAP_net(df,new_angle,new_distance):
    new_id = len(df) + 1
    new_activation = -1.0
    new_description = '障害物'

    new_data = pd.DataFrame({
        'id': [new_id],
        'activation': [new_activation],
        'description': [new_description],
        'angle': [new_angle],
        'distance': [new_distance]
    })

    input_df = pd.concat([df, new_data], ignore_index=True)

    # idとdescriptionを結合した文字列を作成
    input_df['id_description'] = input_df['id'].astype(str) + '_' + input_df['description']

    # ベクトルとして角度と距離を使用するため、データを準備
    vectors = input_df[['angle', 'distance']]

    # ベクトル間のユークリッド距離を計算
    distances = np.linalg.norm(vectors.values[:, np.newaxis] - vectors.values, axis=2)

    # クロス表に距離を格納
    cross_table = pd.DataFrame(distances, index=input_df['id_description'], columns=input_df['id_description'])

    # ユークリッド距離を求めたcross_table
    #print(cross_table)

    # ユークリッド距離の評価指標を計算し、再度DataFrameに格納
    max_distance = np.nanmax(cross_table.values)  # ユークリッド距離の最大値（NaNを除く）
    evaluated_values = 1 - cross_table.values / max_distance
    activation_table = pd.DataFrame(evaluated_values, index=cross_table.index, columns=cross_table.columns)

    # ユークリッド距離を正規化した値をdfに格納
    #print(activation_table)

    # 評価指標を1/10にスケーリング
    activation_table_div10 = activation_table / 10
    activation_table_min1 = 1-activation_table

    input_df2=input_df.copy()

    for i in range(len(activation_table_div10.columns)-1):
        activity_value_temp = activation_table_div10.loc[activation_table_div10.columns[i], activation_table_div10.columns[-1]]
        input_df2.loc[input_df2['id_description'] == activation_table_div10.columns[i], 'activation'] += activity_value_temp

    # 画像を格納するリスト
    images = []

    while not (input_df2['activation'] > 1).any():
        for i in range(len(activation_table_div10.columns)):
            for j in range(len(activation_table_div10.columns)):
                if i==j:
                    continue
                activity_value_temp = activation_table_div10.loc[activation_table_div10.columns[i], activation_table_div10.columns[j]]
                input_df2.loc[input_df2['id_description'] == activation_table_div10.columns[i], 'activation'] += activity_value_temp
            input_df2['activation'] = input_df2['activation'] - 0.01


    return input_df2

def selection(input_df2):
    # descriptionの最大値を持つレコードを出力
    max_description = input_df2['activation'].max()
    max_records = input_df2[input_df2['activation'] == max_description]
    select_knowledge = max_records['id_description'][0]
    return select_knowledge

def dataframe_fix(data):
    # 一番最後の列を削除
    data = data.iloc[:, :-1]
    # 一番最後の行を削除
    data = data.iloc[:-1, :]
    
    return data

def apply_forgetting(data):
    print(data, type(data))
    data['activation'] = data['activation'] - 0.5
    print(data, type(data))
    return data

# %%
# データベースのセットアップ
SQL_SetUp("database.sqlite")

# データの取得と表示
df = SQL_GetData("database.sqlite")
print(df)
distance=1

while distance!=0:
    #角度と距離を入力
    angle = float(input('角度を入力してください: '))
    distance = float(input('距離を入力してください: '))

    #SAP-netにベクトル情報を渡して拡散
    SAP_df = SAP_net(df,angle,distance)

    #SAP-netが選んだ知識を出力
    print(SAP_df)
    max_description = SAP_df['activation'].max()
    print(max_description)
    max_records = SAP_df[SAP_df['activation'] == max_description]
    print(max_records)
    select_knowledge = max_records['id_description']
    print(select_knowledge)

    print(SAP_df)
    print("選ばれた知識は「"+select_knowledge+"」です。")

    #次の回のためにdataframeを合わせる
    #次の回のためにdataframeを合わせる
    df = dataframe_fix(SAP_df)
    df = apply_forgetting(df)
# Out:
# Database already exists. Exiting setup.
#    id   angle  distance  activation description
# 0   1  333.44      1.12         0.0          直進
# 1   2  345.97      1.03         0.0      左寄りの直進
# 2   3    0.00      1.00         0.0      右寄りの直進
# 3   4   14.04      1.03         0.0      右寄りの直進
# 4   5   26.56      1.12         0.0          直進
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.663473          直進           1_直進
# 1   2  345.97      1.03    0.587417      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.912582      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.997803      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.037609          直進           5_直進
# 5   6  200.00      1.00   -0.012258         障害物          6_障害物
# 1.037609252576288
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.037609          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.663473          直進           1_直進
# 1   2  345.97      1.03    0.587417      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.912582      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.997803      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.037609          直進           5_直進
# 5   6  200.00      1.00   -0.012258         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.663473          直進
# 1   2  345.97      1.03    0.587417      左寄りの直進
# 2   3    0.00      1.00    0.912582      右寄りの直進
# 3   4   14.04      1.03    0.997803      右寄りの直進
# 4   5   26.56      1.12    1.037609          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.163473          直進
# 1   2  345.97      1.03    0.087417      左寄りの直進
# 2   3    0.00      1.00    0.412582      右寄りの直進
# 3   4   14.04      1.03    0.497803      右寄りの直進
# 4   5   26.56      1.12    0.537609          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.396350          直進           1_直進
# 1   2  345.97      1.03    0.287699      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.872299      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.994044      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.051944          直進           5_直進
# 5   6  120.00      1.00   -0.558657         障害物          6_障害物
# 1.0519441834694039
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.051944          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.396350          直進           1_直進
# 1   2  345.97      1.03    0.287699      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.872299      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.994044      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.051944          直進           5_直進
# 5   6  120.00      1.00   -0.558657         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.396350          直進
# 1   2  345.97      1.03    0.287699      左寄りの直進
# 2   3    0.00      1.00    0.872299      右寄りの直進
# 3   4   14.04      1.03    0.994044      右寄りの直進
# 4   5   26.56      1.12    1.051944          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.103650          直進
# 1   2  345.97      1.03   -0.212301      左寄りの直進
# 2   3    0.00      1.00    0.372299      右寄りの直進
# 3   4   14.04      1.03    0.494044      右寄りの直進
# 4   5   26.56      1.12    0.551944          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.457746          直進           1_直進
# 1   2  345.97      1.03    0.302014      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.797984      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.972485      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.055717          直進           5_直進
# 5   6  320.00      1.00   -0.511411         障害物          6_障害物
# 1.0557167915130687
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.055717          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.457746          直進           1_直進
# 1   2  345.97      1.03    0.302014      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.797984      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.972485      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.055717          直進           5_直進
# 5   6  320.00      1.00   -0.511411         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.457746          直進
# 1   2  345.97      1.03    0.302014      左寄りの直進
# 2   3    0.00      1.00    0.797984      右寄りの直進
# 3   4   14.04      1.03    0.972485      右寄りの直進
# 4   5   26.56      1.12    1.055717          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.042254          直進
# 1   2  345.97      1.03   -0.197986      左寄りの直進
# 2   3    0.00      1.00    0.297984      右寄りの直進
# 3   4   14.04      1.03    0.472485      右寄りの直進
# 4   5   26.56      1.12    0.555717          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.193225          直進           1_直進
# 1   2  345.97      1.03    0.004897      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.755101      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.966125      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.067450          直進           5_直進
# 5   6  123.00      1.00   -0.560391         障害物          6_障害物
# 1.0674503428717612
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12     1.06745          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.193225          直進           1_直進
# 1   2  345.97      1.03    0.004897      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.755101      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.966125      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.067450          直進           5_直進
# 5   6  123.00      1.00   -0.560391         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.193225          直進
# 1   2  345.97      1.03    0.004897      左寄りの直進
# 2   3    0.00      1.00    0.755101      右寄りの直進
# 3   4   14.04      1.03    0.966125      右寄りの直進
# 4   5   26.56      1.12    1.067450          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.306775          直進
# 1   2  345.97      1.03   -0.495103      左寄りの直進
# 2   3    0.00      1.00    0.255101      右寄りの直進
# 3   4   14.04      1.03    0.466125      右寄りの直進
# 4   5   26.56      1.12    0.567450          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.255776          直進           1_直進
# 1   2  345.97      1.03    0.020367      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.679630      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.943410      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.070067          直進           5_直進
# 5   6  321.00      1.00   -0.512278         障害物          6_障害物
# 1.070066781406038
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.070067          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.255776          直進           1_直進
# 1   2  345.97      1.03    0.020367      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.679630      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.943410      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.070067          直進           5_直進
# 5   6  321.00      1.00   -0.512278         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.255776          直進
# 1   2  345.97      1.03    0.020367      左寄りの直進
# 2   3    0.00      1.00    0.679630      右寄りの直進
# 3   4   14.04      1.03    0.943410      右寄りの直進
# 4   5   26.56      1.12    1.070067          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.244224          直進
# 1   2  345.97      1.03   -0.479633      左寄りの直進
# 2   3    0.00      1.00    0.179630      右寄りの直進
# 3   4   14.04      1.03    0.443410      右寄りの直進
# 4   5   26.56      1.12    0.570067          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.008745          直進           1_直進
# 1   2  345.97      1.03   -0.276749      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.636746      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.937049      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.081800          直進           5_直進
# 5   6  123.00      1.00   -0.560391         障害物          6_障害物
# 1.0818003327647305
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12      1.0818          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.008745          直進           1_直進
# 1   2  345.97      1.03   -0.276749      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.636746      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    0.937049      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.081800          直進           5_直進
# 5   6  123.00      1.00   -0.560391         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.008745          直進
# 1   2  345.97      1.03   -0.276749      左寄りの直進
# 2   3    0.00      1.00    0.636746      右寄りの直進
# 3   4   14.04      1.03    0.937049      右寄りの直進
# 4   5   26.56      1.12    1.081800          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.508745          直進
# 1   2  345.97      1.03   -0.776749      左寄りの直進
# 2   3    0.00      1.00    0.136746      右寄りの直進
# 3   4   14.04      1.03    0.437049      右寄りの直進
# 4   5   26.56      1.12    0.581800          直進 <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       7 distance=1
#       9 while distance!=0:
#      10     #角度と距離を入力
# ---> 11     angle = float(input('角度を入力してください: '))
#      12     distance = float(input('距離を入力してください: '))
#      14     #SAP-netにベクトル情報を渡して拡散
#
# ValueError: could not convert string to float: ''
