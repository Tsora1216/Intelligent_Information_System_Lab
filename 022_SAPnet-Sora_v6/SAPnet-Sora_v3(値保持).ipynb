# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
def SQL_SetUp(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データベースファイルが存在する場合は処理を終了
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
    existing_tables = cursor.fetchall()
    if existing_tables:
        print("Database already exists. Exiting setup.")
        conn.close()
        return

    # テーブルを作成
    cursor.execute('''
        CREATE TABLE knowledge (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            angle FLOAT,
            distance FLOAT,
            activation FLOAT DEFAULT 0,
            description TEXT
        )
    ''')

    data = [
        ("直進", 333.44, 1.12, 0),#１番の知識
        ("左寄りの直進", 345.97, 1.03, 0),#２番の知識
        ("右寄りの直進", 0, 1, 0),#１番の知識
        ("右寄りの直進", 14.04, 1.03, 0),#１番の知識
        ("直進", 26.56, 1.12, 0)#１番の知識
    ]

    # データを挿入
    cursor.executemany("INSERT INTO knowledge (description, angle, distance, activation) VALUES (?, ?, ?, ?)", data)

    conn.commit()
    conn.close()

def SQL_GetData(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データを取得してDataFrameに格納
    cursor.execute("SELECT * FROM knowledge")
    rows = cursor.fetchall()
    columns = [description[0] for description in cursor.description]
    df = pd.DataFrame(rows, columns=columns)

    conn.close()

    return df

# 新しいデータを追加
def SAP_net(df,new_angle,new_distance):
    new_id = len(df) + 1
    new_activation = -1.0
    new_description = '障害物'

    new_data = pd.DataFrame({
        'id': [new_id],
        'activation': [new_activation],
        'description': [new_description],
        'angle': [new_angle],
        'distance': [new_distance]
    })

    input_df = pd.concat([df, new_data], ignore_index=True)

    # idとdescriptionを結合した文字列を作成
    input_df['id_description'] = input_df['id'].astype(str) + '_' + input_df['description']

    # ベクトルとして角度と距離を使用するため、データを準備
    vectors = input_df[['angle', 'distance']]

    # ベクトル間のユークリッド距離を計算
    distances = np.linalg.norm(vectors.values[:, np.newaxis] - vectors.values, axis=2)

    # クロス表に距離を格納
    cross_table = pd.DataFrame(distances, index=input_df['id_description'], columns=input_df['id_description'])

    # ユークリッド距離を求めたcross_table
    #print(cross_table)

    # ユークリッド距離の評価指標を計算し、再度DataFrameに格納
    max_distance = np.nanmax(cross_table.values)  # ユークリッド距離の最大値（NaNを除く）
    evaluated_values = 1 - cross_table.values / max_distance
    activation_table = pd.DataFrame(evaluated_values, index=cross_table.index, columns=cross_table.columns)

    # ユークリッド距離を正規化した値をdfに格納
    #print(activation_table)

    # 評価指標を1/10にスケーリング
    activation_table_div10 = activation_table / 10
    activation_table_min1 = 1-activation_table

    input_df2=input_df.copy()

    for i in range(len(activation_table_div10.columns)-1):
        activity_value_temp = activation_table_div10.loc[activation_table_div10.columns[i], activation_table_div10.columns[-1]]
        input_df2.loc[input_df2['id_description'] == activation_table_div10.columns[i], 'activation'] += activity_value_temp

    # 画像を格納するリスト
    images = []

    while not (input_df2['activation'] > 1).any():
        for i in range(len(activation_table_div10.columns)):
            for j in range(len(activation_table_div10.columns)):
                if i==j:
                    continue
                activity_value_temp = activation_table_div10.loc[activation_table_div10.columns[i], activation_table_div10.columns[j]]
                input_df2.loc[input_df2['id_description'] == activation_table_div10.columns[i], 'activation'] += activity_value_temp

    return input_df2

def selection(input_df2):
    # descriptionの最大値を持つレコードを出力
    max_description = input_df2['activation'].max()
    max_records = input_df2[input_df2['activation'] == max_description]
    select_knowledge = max_records['id_description'][0]
    return select_knowledge

def dataframe_fix(data):
    # 一番最後の列を削除
    data = data.iloc[:, :-1]
    # 一番最後の行を削除
    data = data.iloc[:-1, :]
    
    return data

def apply_forgetting(data):
    print(data, type(data))
    data['activation'] = data['activation'] - 0.7
    print(data, type(data))
    return data

# %%
# データベースのセットアップ
SQL_SetUp("database.sqlite")

# データの取得と表示
df = SQL_GetData("database.sqlite")
print(df)
distance=1

while distance!=0:
    #角度と距離を入力
    angle = float(input('角度を入力してください: '))
    distance = float(input('距離を入力してください: '))

    #SAP-netにベクトル情報を渡して拡散
    SAP_df = SAP_net(df,angle,distance)

    #SAP-netが選んだ知識を出力
    print(SAP_df)
    max_description = SAP_df['activation'].max()
    print(max_description)
    max_records = SAP_df[SAP_df['activation'] == max_description]
    print(max_records)
    select_knowledge = max_records['id_description']
    print(select_knowledge)

    print(SAP_df)
    print("選ばれた知識は「"+select_knowledge+"」です。")

    #次の回のためにdataframeを合わせる
    df = dataframe_fix(SAP_df)
    df = apply_forgetting(df)
# Out:
# Database already exists. Exiting setup.
#    id   angle  distance  activation description
# 0   1  333.44      1.12         0.0          直進
# 1   2  345.97      1.03         0.0      左寄りの直進
# 2   3    0.00      1.00         0.0      右寄りの直進
# 3   4   14.04      1.03         0.0      右寄りの直進
# 4   5   26.56      1.12         0.0          直進
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.495660          直進           1_直進
# 1   2  345.97      1.03    0.434204      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.241377      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.283363      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.284849          直進           5_直進
# 5   6    0.00     20.00    0.127650         障害物          6_障害物
# 1.2848485924742306
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.284849          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.495660          直進           1_直進
# 1   2  345.97      1.03    0.434204      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.241377      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.283363      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.284849          直進           5_直進
# 5   6    0.00     20.00    0.127650         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.495660          直進
# 1   2  345.97      1.03    0.434204      左寄りの直進
# 2   3    0.00      1.00    1.241377      右寄りの直進
# 3   4   14.04      1.03    1.283363      右寄りの直進
# 4   5   26.56      1.12    1.284849          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.204340          直進
# 1   2  345.97      1.03   -0.265796      左寄りの直進
# 2   3    0.00      1.00    0.541377      右寄りの直進
# 3   4   14.04      1.03    0.583363      右寄りの直進
# 4   5   26.56      1.12    0.584849          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.044519          直進           1_直進
# 1   2  345.97      1.03   -0.049530      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.221709      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.278859      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.276959          直進           5_直進
# 5   6    0.00      5.00   -0.419019         障害物          6_障害物
# 1.278859439296013
#    id  angle  distance  activation description id_description
# 3   4  14.04      1.03    1.278859      右寄りの直進       4_右寄りの直進
# 3    4_右寄りの直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12    0.044519          直進           1_直進
# 1   2  345.97      1.03   -0.049530      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.221709      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.278859      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.276959          直進           5_直進
# 5   6    0.00      5.00   -0.419019         障害物          6_障害物
# 3    選ばれた知識は「4_右寄りの直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12    0.044519          直進
# 1   2  345.97      1.03   -0.049530      左寄りの直進
# 2   3    0.00      1.00    1.221709      右寄りの直進
# 3   4   14.04      1.03    1.278859      右寄りの直進
# 4   5   26.56      1.12    1.276959          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.655481          直進
# 1   2  345.97      1.03   -0.749530      左寄りの直進
# 2   3    0.00      1.00    0.521709      右寄りの直進
# 3   4   14.04      1.03    0.578859      右寄りの直進
# 4   5   26.56      1.12    0.576959          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.406476          直進           1_直進
# 1   2  345.97      1.03   -0.533108      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.197820      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.272671      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.268172          直進           5_直進
# 5   6    0.00     10.00   -0.423773         障害物          6_障害物
# 1.2726707786958844
#    id  angle  distance  activation description id_description
# 3   4  14.04      1.03    1.272671      右寄りの直進       4_右寄りの直進
# 3    4_右寄りの直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.406476          直進           1_直進
# 1   2  345.97      1.03   -0.533108      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.197820      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.272671      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.268172          直進           5_直進
# 5   6    0.00     10.00   -0.423773         障害物          6_障害物
# 3    選ばれた知識は「4_右寄りの直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.406476          直進
# 1   2  345.97      1.03   -0.533108      左寄りの直進
# 2   3    0.00      1.00    1.197820      右寄りの直進
# 3   4   14.04      1.03    1.272671      右寄りの直進
# 4   5   26.56      1.12    1.268172          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.106476          直進
# 1   2  345.97      1.03   -1.233108      左寄りの直進
# 2   3    0.00      1.00    0.497820      右寄りの直進
# 3   4   14.04      1.03    0.572671      右寄りの直進
# 4   5   26.56      1.12    0.568172          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.857633          直進           1_直進
# 1   2  345.97      1.03   -1.016860      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.179007      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.268364      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.260381          直進           5_直進
# 5   6    0.00      4.00   -0.418230         障害物          6_障害物
# 1.268363675029389
#    id  angle  distance  activation description id_description
# 3   4  14.04      1.03    1.268364      右寄りの直進       4_右寄りの直進
# 3    4_右寄りの直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -0.857633          直進           1_直進
# 1   2  345.97      1.03   -1.016860      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.179007      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.268364      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.260381          直進           5_直進
# 5   6    0.00      4.00   -0.418230         障害物          6_障害物
# 3    選ばれた知識は「4_右寄りの直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -0.857633          直進
# 1   2  345.97      1.03   -1.016860      左寄りの直進
# 2   3    0.00      1.00    1.179007      右寄りの直進
# 3   4   14.04      1.03    1.268364      右寄りの直進
# 4   5   26.56      1.12    1.260381          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.557633          直進
# 1   2  345.97      1.03   -1.716860      左寄りの直進
# 2   3    0.00      1.00    0.479007      右寄りの直進
# 3   4   14.04      1.03    0.568364      右寄りの直進
# 4   5   26.56      1.12    0.560381          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.308666          直進           1_直進
# 1   2  345.97      1.03   -1.500478      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.155955      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.262594      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.251825          直進           5_直進
# 5   6    0.00      9.00   -0.422724         障害物          6_障害物
# 1.2625939368102286
#    id  angle  distance  activation description id_description
# 3   4  14.04      1.03    1.262594      右寄りの直進       4_右寄りの直進
# 3    4_右寄りの直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.308666          直進           1_直進
# 1   2  345.97      1.03   -1.500478      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.155955      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.262594      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.251825          直進           5_直進
# 5   6    0.00      9.00   -0.422724         障害物          6_障害物
# 3    選ばれた知識は「4_右寄りの直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.308666          直進
# 1   2  345.97      1.03   -1.500478      左寄りの直進
# 2   3    0.00      1.00    1.155955      右寄りの直進
# 3   4   14.04      1.03    1.262594      右寄りの直進
# 4   5   26.56      1.12    1.251825          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -2.008666          直進
# 1   2  345.97      1.03   -2.200478      左寄りの直進
# 2   3    0.00      1.00    0.455955      右寄りの直進
# 3   4   14.04      1.03    0.562594      右寄りの直進
# 4   5   26.56      1.12    0.551825          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.759030          直進           1_直進
# 1   2  345.97      1.03   -1.983376      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.123902      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.250870      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.239547          直進           5_直進
# 5   6    0.00     20.00   -0.436175         障害物          6_障害物
# 1.2508696551603813
#    id  angle  distance  activation description id_description
# 3   4  14.04      1.03     1.25087      右寄りの直進       4_右寄りの直進
# 3    4_右寄りの直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.759030          直進           1_直進
# 1   2  345.97      1.03   -1.983376      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.123902      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.250870      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.239547          直進           5_直進
# 5   6    0.00     20.00   -0.436175         障害物          6_障害物
# 3    選ばれた知識は「4_右寄りの直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.759030          直進
# 1   2  345.97      1.03   -1.983376      左寄りの直進
# 2   3    0.00      1.00    1.123902      右寄りの直進
# 3   4   14.04      1.03    1.250870      右寄りの直進
# 4   5   26.56      1.12    1.239547          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -2.459030          直進
# 1   2  345.97      1.03   -2.683376      左寄りの直進
# 2   3    0.00      1.00    0.423902      右寄りの直進
# 3   4   14.04      1.03    0.550870      右寄りの直進
# 4   5   26.56      1.12    0.539547          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.698750          直進           1_直進
# 1   2  345.97      1.03   -1.940498      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.023893      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.201561      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.214583          直進           5_直進
# 5   6  360.00      1.00   -0.399992         障害物          6_障害物
# 1.2145827524764572
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.214583          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.698750          直進           1_直進
# 1   2  345.97      1.03   -1.940498      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    1.023893      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.201561      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.214583          直進           5_直進
# 5   6  360.00      1.00   -0.399992         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.698750          直進
# 1   2  345.97      1.03   -1.940498      左寄りの直進
# 2   3    0.00      1.00    1.023893      右寄りの直進
# 3   4   14.04      1.03    1.201561      右寄りの直進
# 4   5   26.56      1.12    1.214583          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -2.398750          直進
# 1   2  345.97      1.03   -2.640498      左寄りの直進
# 2   3    0.00      1.00    0.323893      右寄りの直進
# 3   4   14.04      1.03    0.501561      右寄りの直進
# 4   5   26.56      1.12    0.514583          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.641208          直進           1_直進
# 1   2  345.97      1.03   -1.902700      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.924275      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.152601      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.189945          直進           5_直進
# 5   6  360.00     14.00   -0.406702         障害物          6_障害物
# 1.1899447316511715
#    id  angle  distance  activation description id_description
# 4   5  26.56      1.12    1.189945          直進           5_直進
# 4    5_直進
# Name: id_description, dtype: object
#    id   angle  distance  activation description id_description
# 0   1  333.44      1.12   -1.641208          直進           1_直進
# 1   2  345.97      1.03   -1.902700      左寄りの直進       2_左寄りの直進
# 2   3    0.00      1.00    0.924275      右寄りの直進       3_右寄りの直進
# 3   4   14.04      1.03    1.152601      右寄りの直進       4_右寄りの直進
# 4   5   26.56      1.12    1.189945          直進           5_直進
# 5   6  360.00     14.00   -0.406702         障害物          6_障害物
# 4    選ばれた知識は「5_直進」です。
# Name: id_description, dtype: object
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -1.641208          直進
# 1   2  345.97      1.03   -1.902700      左寄りの直進
# 2   3    0.00      1.00    0.924275      右寄りの直進
# 3   4   14.04      1.03    1.152601      右寄りの直進
# 4   5   26.56      1.12    1.189945          直進 <class 'pandas.core.frame.DataFrame'>
#    id   angle  distance  activation description
# 0   1  333.44      1.12   -2.341208          直進
# 1   2  345.97      1.03   -2.602700      左寄りの直進
# 2   3    0.00      1.00    0.224275      右寄りの直進
# 3   4   14.04      1.03    0.452601      右寄りの直進
# 4   5   26.56      1.12    0.489945          直進 <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       7 distance=1
#       9 while distance!=0:
#      10     #角度と距離を入力
# ---> 11     angle = float(input('角度を入力してください: '))
#      12     distance = float(input('距離を入力してください: '))
#      14     #SAP-netにベクトル情報を渡して拡散
#
# ValueError: could not convert string to float: ''
