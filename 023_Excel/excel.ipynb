# %%
import sqlite3
import numpy as np
import pandas as pd

def SQL_SetUp(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データベースファイルが存在する場合は処理を終了
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
    existing_tables = cursor.fetchall()
    if existing_tables:
        print("Database already exists. Exiting setup.")
        conn.close()
        return

    # テーブルを作成
    cursor.execute('''
        CREATE TABLE knowledge (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            question TEXT,
            imgpath TEXT,
            start_height 
            distance FLOAT,
            activation FLOAT DEFAULT 0,
            description TEXT
        )
    ''')

    data = [
        ("データバー＞塗りつぶし（グラデーション）＞青のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	20,-11,1186,580,50,50),
        ("データバー＞塗りつぶし（グラデーション）＞緑のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	20,29,1186,580,50,50),
        ("データバー＞塗りつぶし（グラデーション）＞赤のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	20,69,1186,580,50,50),
        ("データバー＞塗りつぶし（グラデーション）＞オレンジのデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	58,-11,1186,580,50,50),
        ("データバー＞塗りつぶし（グラデーション）＞水色のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	58,29,1186,580,50,50),
        ("データバー＞塗りつぶし（グラデーション）＞紫のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	58,69,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞青のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	120,-11,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞緑のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	120,29,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞赤のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	120,69,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞オレンジのデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	158,-11,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞水色のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	158,29,1186,580,50,50),
        ("データバー＞塗りつぶし（単色）＞紫のデータバー",	"C:\Users\Owner\Box\MOS世界学生大会対策用\納品\データバー.png",	158,69,1186,580,50,50)
    ]

    # データを挿入
    cursor.executemany("INSERT INTO knowledge (description, angle, distance, activation) VALUES (?, ?, ?, ?)", data)

    conn.commit()
    conn.close()

def SQL_GetData(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # データを取得してDataFrameに格納
    cursor.execute("SELECT * FROM knowledge")
    rows = cursor.fetchall()
    columns = [description[0] for description in cursor.description]
    df = pd.DataFrame(rows, columns=columns)

    conn.close()

    return df
